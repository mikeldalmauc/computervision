# %%
# face detection

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('C:/Users/Mikel/Anaconda3/pkgs/libopencv-3.4.2-h20b85fd_0/Library/etc/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:/Users/Mikel/Anaconda3/pkgs/libopencv-3.4.2-h20b85fd_0/Library/etc/haarcascades/haarcascade_eye.xml')

# %%
cd ../data
# Out:
# C:\Users\Mikel\Dropbox\docencia vision 2018\desafio 10\data

# %%
img = cv2.imread('lena.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1c8274afef0>, None)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        roi__eyes_gray = gray[ey:ey+eh, ex:ex+ew]
        roi_eyes = roi_color[ey:ey+eh, ex:ex+ew]
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        roi_eyes = cv2.medianBlur(roi_eyes,5)
        roi__eyes_gray = cv2.cvtColor(roi_eyes,cv2.COLOR_GRAY2BGR)
        circles = cv2.HoughCircles(roi__eyes_gray,cv2.HOUGH_GRADIENT,1,20,param1=50,param2=30,minRadius=0,maxRadius=0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-f86212191a52> in <module>
#       7         roi_eyes = roi_color[ey:ey+eh, ex:ex+ew]
#       8         roi_eyes = cv2.medianBlur(roi_eyes,5)
# ----> 9         circles = cv2.HoughCircles(roi_eyes,cv2.HOUGH_GRADIENT,1,20,param1=50,param2=30,minRadius=0,maxRadius=0)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\hough.cpp:1737: error: (-215:Assertion failed) !_image.empty() && _image.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) && (_image.isMat() || _image.isUMat()) in function 'cv::HoughCircles'

# %%
        circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                # draw the outer circle
                cv2.circle(roi_eyes,(i[0],i[1]),i[2],(0,255,0),2)
                # draw the center of the circle
                cv2.circle(roi_eyes,(i[0],i[1]),2,(0,0,255),3)

# %%
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
